# %%
import keras
from keras.models import Sequential  
from keras import layers
from keras.layers import Dense  
import numpy
import pandas as pd  

import warnings
warnings.filterwarnings("ignore")

# %%
name_columns = ['Sexo', 'Largura', 'Diámetro', 'Altura', 'Whole_weight', 'Shucked_weight', 'Viscera_weight', 'Shell_weight','Anillos']

dataset = pd.read_csv("C:/Users/Jose Manuel/Documents/VisualStudioCode_Workspace/Repo_CEDAPY/CEDAPY_25_26/ANALISIS_DATOS_PYTHON/NOTEBOOKS/EJERCICIOS/RN/abalone.data",
                        delimiter=",", header=None, names=name_columns)
display(dataset)
# Out:
#      Sexo  Largura  Diámetro  Altura  Whole_weight  Shucked_weight  \
# 0       M    0.455     0.365   0.095        0.5140          0.2245
# 1       M    0.350     0.265   0.090        0.2255          0.0995
# 2       F    0.530     0.420   0.135        0.6770          0.2565
# 3       M    0.440     0.365   0.125        0.5160          0.2155
# 4       I    0.330     0.255   0.080        0.2050          0.0895
# ...   ...      ...       ...     ...           ...             ...
# 4172    F    0.565     0.450   0.165        0.8870          0.3700
# 4173    M    0.590     0.440   0.135        0.9660          0.4390
# 4174    M    0.600     0.475   0.205        1.1760          0.5255
# 4175    F    0.625     0.485   0.150        1.0945          0.5310
# 4176    M    0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight  Anillos
# 0             0.1010        0.1500       15
# 1             0.0485        0.0700        7
# ...

# %%
map_target_class = {'M': 0, 'F': 1, 'I':3}
dataset['Sexo']= dataset['Sexo'].map(map_target_class)
dataset.head()
# Out:
#    Sexo  Largura  Diámetro  Altura  Whole_weight  Shucked_weight  \
# 0     0    0.455     0.365   0.095        0.5140          0.2245
# 1     0    0.350     0.265   0.090        0.2255          0.0995
# 2     1    0.530     0.420   0.135        0.6770          0.2565
# 3     0    0.440     0.365   0.125        0.5160          0.2155
# 4     3    0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera_weight  Shell_weight  Anillos
# 0          0.1010         0.150       15
# 1          0.0485         0.070        7
# 2          0.1415         0.210        9
# 3          0.1140         0.155       10
# 4          0.0395         0.055        7

# %%
X = dataset.iloc[:,0:8]  
Y = dataset.iloc[:,8]

# %%
print(X.shape)
print(Y.shape)
# Out:
# (4177, 8)
# (4177,)

# %%
model2 = keras.Sequential([
    keras.layers.Input(shape=(8,)),
    keras.layers.Dense(12, activation='relu'),
    keras.layers.Dense(8, activation='relu'),
    keras.layers.Dense(1, activation='linear')    
])

# %%
model2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
training_model = model2.fit(X, Y, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 1s 858us/step - accuracy: 2.3941e-04 - loss: -292.7582
# Epoch 2/150
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step - accuracy: 2.3941e-04 - loss: -4477.8677
# Epoch 3/150
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - accuracy: 2.3941e-04 - loss: -18471.1309
# Epoch 4/150
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - accuracy: 2.3941e-04 - loss: -46381.5000
# Epoch 5/150
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step - accuracy: 2.3941e-04 - loss: -90896.3203
# Epoch 6/150
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step - accuracy: 2.3941e-04 - loss: -153523.9688
# Epoch 7/150
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - accuracy: 2.3941e-04 - loss: -235639.5938
# Epoch 8/150
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - accuracy: 2.3941e-04 - loss: -338527.8750
# Epoch 9/150
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - accuracy: 2.3941e-04 - loss: -463328.8125
# Epoch 10/150
# ...

# %%
model2.evaluate(X, Y, batch_size=32)
# Out:
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step - accuracy: 2.3941e-04 - loss: -704541696.0000
# [-704541696.0, 0.00023940627579577267]
